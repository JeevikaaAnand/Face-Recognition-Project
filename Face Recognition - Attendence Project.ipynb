# %% [markdown]
# ## Face Recognition- Attendence Project

# %% [markdown]
# #### Installed Required libraries like OpenCV - Python, cmake, dlib, Face_Recognition

# %% [markdown]
# ![fr1.png](attachment:fr1.png)

# %% [markdown]
# #### Create train_images folder with required images, create a list and append the path of the train_image folder.
# #### Then read the image using OpenCV and append in the created empty list.

# %% [markdown]
# ![fr2.png](attachment:fr2.png)

# %% [markdown]
# #### Virat kohli image is given as the Training_image

# %% [markdown]
# ![Virat-Kohli.png](attachment:Virat-Kohli.png)

# %% [markdown]
# #### Define a function and create a for loop in which each train image should be converted to BGR using OpenCV and Encode the face using face_encoding from face_recognition module, append to the empty list defined
#
# #### Define a other function to mark the attendence through Excel or csv which can be directly saved into the file that already created in environment
#
# #### in the created csv or excel, entry must be given in 2 splits - name and time

# %% [markdown]
# ![fr3.png](attachment:fr3.png)

# %% [markdown]
# ### To enable web cam, use OpenCV
#    1) Use cv2.VideoCapture() to get a video capture object for the camera.
#    2) Set up an infinite while loop and use the read() method to read the frames using the above created object.
#    3) Use cv2.imshow() method to show the frames in the video.

# %% [markdown]
# ![fr6.png](attachment:fr6.png)

# %% [markdown]
# ### OUTPUT

# %% [markdown]
# #### The webcam will start once the code is runned

# %% [markdown]
# ![fr%205.png](attachment:fr%205.png)

# %% [markdown]
# #### If the person is recognised it will directly save in the Excel/csv with name and time

# %% [markdown]
# ![fr%20attendance.png](attachment:fr%20attendance.png)
